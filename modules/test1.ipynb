# %%
nested = [
        [1,2,3,]
        [8,9,10]
        [11,12,13]
]

# %%
from codes import print_nested_list

# %%
nested = [1,2,3,[4,5],6]
print_nested_list(nested,2)
# Out:
# 			2
# 		1

# %%
import codes
nest =[1,2,3,['A','B']]

# %%
codes.print_nested_list(nest,1)
# Out:
# 		1
# 	0
